# %%
import pandas as pd

# %%
df = pd.read_csv('iw_uk.csv', index_col=0)
# Out:
# /var/folders/82/y6qdnkm17_j10_7ddv31f_mw0000gn/T/ipykernel_35550/2441918933.py:1: DtypeWarning: Columns (0: source, 1: registrant_additional_information, 2: portal_source) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('iw_uk.csv', index_col=0)

# %%
df.head()
# Out:
#                     rep_new  policy_level        date  \
# 0  Rt Hon Dominic Grieve QC             1  01/01/2012
# 1  Rt Hon Dominic Grieve QC             1  01/02/2012
# 2  Rt Hon Dominic Grieve QC             1  01/02/2012
# 3  Rt Hon Dominic Grieve QC             1  01/02/2012
# 4  Rt Hon Dominic Grieve QC             1  01/03/2012
#
#                                       organisation  \
# 0                          Criminal Law Commission
# 1                               Federalist Society
# 2                          Magistrates Association
# 3                                      Bar Council
# 4  Sir Daniel Bethlehem QC & Sir Jeffery Jowell QC
#
#                                         purpose                 department  \
# 0                    To discuss contempt issues  Attorney General's Office
# 1       To discuss the EU Court of Human Rights  Attorney General's Office
# 2  To discuss the magistrates sentencing powers  Attorney General's Office
# ...

# %%
df.shape, df.RecordId.max()
# Out:
# ((166368, 13), np.int64(22744976))

# %%
df.tail()
# Out:
#                         rep_new  policy_level        date  \
# 166363    Rt Hon Maria Eagle MP             1  15/07/2025
# 166364              Al Carns MP             1  18/09/2025
# 166365  Louise Sandher-Jones MP             1  07/07/2025
# 166366  Louise Sandher-Jones MP             1  01/09/2025
# 166367  Louise Sandher-Jones MP             1  01/09/2025
#
#                                              organisation  \
# 166363                                 Vertical Aerospace
# 166364  The Royal British Legion, SRRA, SASRA, SBSA, M...
# 166365                                Fighting With Pride
# 166366                       NASUWT - The Teachers' Union
# 166367                              Labrats International
#
#                                                   purpose  \
# 166363                               Introduction meeting
# 166364             To discuss the Northern Ireland Legacy
# 166365              Priorities and Remberance Discussions
# ...

# %%
df.loc[df.RecordId.isin([43510, 43511]), ]
# Out:
#                      rep_new  policy_level        date  \
# 43491  Jackie Doyle-Price MP             1  15/11/2017
# 43492  Jackie Doyle-Price MP             1  15/11/2017
#
#                                             organisation  \
# 43491                         Marie Stopes International
# 43492  Transforming Care Assurance Roundtable\nSeeAbi...
#
#                                                  purpose  \
# 43491        A progress meeting following CQC inspection
# 43492  To hear stakeholders? views and perceptions of...
#
#                                  department Quarter others_at_the_meeting  \
# 43491  Department of Health and Social Care      Q4                   NaN
# 43492  Department of Health and Social Care      Q4                   NaN
#
#       source registrant_additional_information  portal_source  RecordId  \
# 43491    NaN                               NaN  UK Government     43510
# 43492    NaN                               NaN  UK Government     43511
#
# ...

# %%
df.to_json("iw_uk.json", orient="records")
